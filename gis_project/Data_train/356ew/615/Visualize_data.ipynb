# %%
import pandas as pd
import numpy as np 
from matplotlib import pyplot
import seaborn as sns
# %matplotlib inline

# %%
sns.set()

# %%
import numpy as np
import matplotlib.pyplot as plt

filelist=[]
color=['b','g','r','c','m','y','k','w']
for i in range(1,2):
    filelist.append("356_EW_%sjuly_150220615.csv" %i)
count=0;
for fname in filelist:
    data=pd.read_csv(fname)
#     data=np.loadtxt(fname)
    data=data.as_matrix()
    Y=data[:,7]
    X=data[:,8]
    X=X/3600
    plt.plot(X,Y,color[count])
    count=count+1
# plt.xticks(X)
plt.show()
# print (X)

# %%
data_x=pd.read_csv('356_EW_24july_150220615.csv')
data_y=pd.read_csv('356_EW_22july_150220615.csv')

# %%
data_y
# Out:
#     Start_Lat  Start_Longitude Start_Time    End_Lat  End_Longitude  End_Time  \
# 0   12.847360        77.672462   07:21:30  12.847462      77.670876  07:31:28
# 1   12.911982        77.638191   07:52:13  12.911968      77.639725  08:02:00
# 2   12.916577        77.623421   08:32:53  12.911506      77.626244  08:39:32
# 3   12.839917        77.659843   08:55:17  12.840510      77.659904  09:05:06
# 4   12.916590        77.631393   09:30:11  12.916595      77.623459  09:40:08
# 5   12.916601        77.623451   09:40:18  12.915056      77.624237  09:50:16
# 6   12.839359        77.659416   10:13:31  12.838624      77.658691  10:23:28
# 7   12.838623        77.658691   10:23:38  12.845237      77.665428  10:33:36
# 8   12.917392        77.624039   11:04:29  12.911885      77.626106  11:14:26
# 9   12.916666        77.623337   12:00:25  12.912109      77.625824  12:08:13
# 10  12.838803        77.658829   12:27:18  12.839870      77.659561  12:37:16
# ...

# %%
data=pd.read_csv('356_EW_31july_150220615.csv')

# %%
da
# Out:
#     Start_Lat  Start_Longitude Start_Time    End_Lat  End_Longitude  End_Time  \
# 0   12.840007        77.659866   08:34:25  12.838665      77.658829  08:44:23
# 1   12.838666        77.658829   08:44:33  12.845147      77.660362  08:54:32
# 2   12.911958        77.639404   09:17:37  12.911946      77.639763  09:27:28
# 3   12.916985        77.623444   09:47:50  12.916752      77.623451  09:57:47
# 4   12.916438        77.623489   10:08:06  12.907550      77.628716  10:17:23
# 5   12.838695        77.659042   10:36:39  12.838880      77.658882  10:46:36
# 6   12.838881        77.658867   10:46:46  12.846266      77.668785  10:56:44
# 7   12.916884        77.622864   11:07:31  12.915722      77.623840  11:17:30
# 8   12.915722        77.623840   11:17:39  12.911868      77.626083  11:21:38
# 9   12.916692        77.632294   12:05:28  12.917001      77.623489  12:15:25
# 10  12.916796        77.623367   12:25:45  12.915488      77.624008  12:35:41
# ...

# %%
 locs, labels = xticks()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-c649facea929> in <module>()
# ----> 1 locs, labels = xticks()
#
# NameError: name 'xticks' is not defined
