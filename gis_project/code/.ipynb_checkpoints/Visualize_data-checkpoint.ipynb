# %%
import pandas as pd
import numpy as np 
from matplotlib import pyplot
# %matplotlib inline

# %%
july1=pd.read_csv('356_EW_1july_150218661.csv')
july4=pd.read_csv('356_EW_4july_150218661.csv')
july5=pd.read_csv('356_EW_5july_150218661.csv')
# fig, ax = pyplot.subplots(1)
fig, ax = pyplot.subplots(1)

# %%
july1_data_x=july1[['Start_Time']].copy()
july1_data_y=july1[['Flag']].copy()
july4_data_x=july1[['Start_Time']].copy()
july4_data_y=july1[['Flag']].copy()
x1=july1_data_x.as_matrix().reshape(-1)
y1=july1_data_y.as_matrix().reshape(-1)
x2=july4_data_x.as_matrix().reshape(-1)
y2=july4_data_y.as_matrix().reshape(-1)

# fig, ax = pyplot.subplots(1)
pyplot.plot(x1,y1,'r')
#ax = f1.add_subplot()
# pyplot.show()

pyplot.plot(x2,y2,'g')
pyplot.show()

# %%
x=np.arange(0,20,1)
y=np.
