# %%
import pandas as pd
import numpy as np 
from matplotlib import pyplot

# %%
july1=pd.read_csv('/home/b/Desktop/Gi/gis_project/Data_train/356ew/356_EW_1july_150218661.csv')
july4=pd.read_csv('/home/b/Desktop/Gi/gis_project/Data_train/356ew/356_EW_4july_150218661.csv')
july5=pd.read_csv('/home/b/Desktop/Gi/gis_project/Data_train/356ew/356_EW_5july_150218661.csv')

# %%
july1_data_x=july1[['Start_Time']].copy()
july1_data_y=july1[['Flag']].copy()
x=july1_data_x.as_matrix().reshape(-1)
y=july1_data_y.as_matrix().reshape(-1)
fig, ax = pyplot.subplots(1)
pyplot.plot(x[:10],y[:10],'ro')
pyplot.show()

# %%
x=np.arange(0,20,1)
y=np.
